# %%
path=r"C:\Users\HP\Downloads\IPL2025Batters.csv"

df=pd.read_csv(path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 path=r"C:\Users\HP\Downloads\IPL2025Batters.csv"
# ----> 3 df=pd.read_csv(path)
#       4 df.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

path=r"C:\Users\HP\Downloads\IPL2025Batters.csv"

df=pd.read_csv(path)
df.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %%
df.shape
# Out:
# (156, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
df.drop(columns=['match_id','extras_type','player_dismissed','dismissal_kind','fielder'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.drop(columns=['match_id','extras_type','player_dismissed','dismissal_kind','fielder'],inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
df.head(50)
# Out:
#              Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1      Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2            Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3           Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4         Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 5           Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 6       Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350
# 7      Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 8              K L Rahul    DC   539       13   13   3  112*  53.90  360
# 9            Jos Buttler    GT   538       14   13   4   97*  59.78  330
# 10       Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267
# 11      Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
low=10.750000-(1.5*93.500000)
upper=254.250000+(1.5*93.500000)
print(low,upper)
# Out:
# -129.5 394.5

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.boxplot(df['Matches'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x264b7447d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x264b7484050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x264b734bc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x264b74842d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x264b7484410>],
#  'means': []}

# %%
plt.hist(df['Matches'])
# Out:
# (array([15., 14.,  9., 14.,  8., 12., 14., 22., 38., 10.]),
#  array([ 1. ,  2.6,  4.2,  5.8,  7.4,  9. , 10.6, 12.2, 13.8, 15.4, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df['HS']=df['HS'].str.replace('*','')

# %%
df['HS'].min()
# Out:
# '1'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
df['HS']=df['HS'].astype('int')

# %%
df['HS'].dtype
# Out:
# dtype('int64')

# %%
df['HS'].max()
# Out:
# 141

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0  117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..  ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0    1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1    1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0    1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df.sort_values(by='Runs',ascending=False).head(10)
# Out:
#          Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 0      Sai Sudharsan    GT   759       15   15   1  108  54.21  486  156.17
# 1  Surya Kumar Yadav    MI   717       16   16   5   73  65.18  427  167.91
# 2        Virat Kohli   RCB   657       15   15   3   73  54.75  454  144.71
# 3       Shubman Gill    GT   650       15   15   2   93  50.00  417  155.87
# 4     Mitchell Marsh   LSG   627       13   13   0  117  48.23  383  163.70
# 5       Shreyas Iyer  PBKS   604       17   17   5   97  50.33  345  175.07
# 6   Yashasvi Jaiswal    RR   559       14   14   1   75  43.00  350  159.71
# 7  Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342  160.52
# 8          K L Rahul    DC   539       13   13   3  112  53.90  360  149.72
# 9        Jos Buttler    GT   538       14   13   4   97  59.78  330  163.03
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# ...

# %%
df.sort_values(by=['Runs','SR'],ascending=False).head(10)
# Out:
#          Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 0      Sai Sudharsan    GT   759       15   15   1  108  54.21  486  156.17
# 1  Surya Kumar Yadav    MI   717       16   16   5   73  65.18  427  167.91
# 2        Virat Kohli   RCB   657       15   15   3   73  54.75  454  144.71
# 3       Shubman Gill    GT   650       15   15   2   93  50.00  417  155.87
# 4     Mitchell Marsh   LSG   627       13   13   0  117  48.23  383  163.70
# 5       Shreyas Iyer  PBKS   604       17   17   5   97  50.33  345  175.07
# 6   Yashasvi Jaiswal    RR   559       14   14   1   75  43.00  350  159.71
# 7  Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342  160.52
# 8          K L Rahul    DC   539       13   13   3  112  53.90  360  149.72
# 9        Jos Buttler    GT   538       14   13   4   97  59.78  330  163.03
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# ...

# %%
1.Data distribution and data dispersion

2. Covariance(-inf ,+inf) and correlation (-1 to 1)
-> correlation -> It tells how much of bond each other.
-> Covariance -> In which direction the columns are take a better bonding.

# %%
df[['Runs','SR']].corr()
# Out:
#           Runs        SR
# Runs  1.000000  0.349464
# SR    0.349464  1.000000

# %%
df[df['AVG']=='']
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, Runs, Matches, Inn, No, HS, AVG, BF, SR, 100s, 50s, 4s, 6s]
# Index: []

# %%
df.describe()
# Out:
#              Runs     Matches         Inn          No          HS          BF  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615   40.737179  105.673077
# std    180.352772    4.757455    4.810142    1.658163   33.637750  112.191838
# min      1.000000    1.000000    1.000000    0.000000    1.000000    1.000000
# 25%     10.750000    6.000000    2.750000    0.000000    8.000000   12.000000
# 50%     93.500000   11.000000    6.000000    1.000000   37.000000   63.500000
# 75%    254.250000   14.000000   12.000000    3.000000   65.000000  164.750000
# max    759.000000   17.000000   17.000000    7.000000  141.000000  486.000000
#
#                SR        100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   134.394103    0.057692    0.916667   14.391026    8.294872
# std     57.237148    0.233912    1.590124   17.778774    9.515500
# ...

# %%
plt.boxplot(df['Runs'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x264b8cc4550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x264b8cc47d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x264b8cc4410>],
#  'medians': [<matplotlib.lines.Line2D at 0x264b8cc4a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x264b8cc4b90>],
#  'means': []}

# %%
from scipy.stats import zscore
   zscore = (x-mue(mean)/std

# %%
df['Zscore']=zscore(df['Runs'])

# %%
df[df['Zscore']>3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Zscore'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df[df['Zscore']>3]
#
# ...

# %%
team=df.groupby('Team')['Runs'].max().index
team
# Out:
# Index(['CSK', 'DC', 'GT', 'KKR', 'LSG', 'MI', 'PBKS', 'RCB', 'RR', 'SRH'], dtype='object', name='Team')

# %%
score=df.groupby('Team')['Runs'].max().values
score
# Out:
# array([357, 539, 759, 390, 627, 717, 604, 657, 559, 487])

# %%
for i,j in zip(team,score):
    print(df[(df['Team']==i) &( df['Runs']==j)])
# Out:
#     Player Name Team  Runs  Matches  Inn  No  HS          AVG   BF      SR  \
# 22  Shivam Dube  CSK   357       14   14   3  50  03020.04050  270  132.22
#
#     100s  50s  4s  6s
# 22     0    1  22  21
#   Player Name Team  Runs  Matches  Inn  No   HS          AVG   BF      SR  \
# 8   K L Rahul   DC   539       13   13   3  112  05030.09000  360  149.72
#
#    100s  50s  4s  6s
# 8     1    3  52  21
#      Player Name Team  Runs  Matches  Inn  No   HS          AVG   BF      SR  \
# 0  Sai Sudharsan   GT   759       15   15   1  108  05040.02010  486  156.17
#
#    100s  50s  4s  6s
# 0     1    6  88  21
#        Player Name Team  Runs  Matches  Inn  No  HS          AVG   BF      SR  \
# 18  Ajinkya Rahane  KKR   390       13   12   1  61  03050.04050  264  147.72
#
#     100s  50s  4s  6s
# 18     0    3  36  20
#       Player Name Team  Runs  Matches  Inn  No   HS          AVG   BF     SR  \
# 4  Mitchell Marsh  LSG   627       13   13   0  117  04080.02030  383  163.7
#
# ...

# %%
df['Rank']=df.groupby('Team')['Runs'].rank('dense',ascending=False)

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No   HS          AVG   BF  \
# 0        Sai Sudharsan   GT   759       15   15   1  108  05040.02010  486
# 1    Surya Kumar Yadav   MI   717       16   16   5   73  06050.01080  427
# 2          Virat Kohli  RCB   657       15   15   3   73  05040.07050  454
# 3         Shubman Gill   GT   650       15   15   2   93  05000.00000  417
# 4       Mitchell Marsh  LSG   627       13   13   0  117  04080.02030  383
# ..                 ...  ...   ...      ...  ...  ..  ...          ...  ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1          0-0    2
# 152       Mohit Sharma   DC     1        8    2   1    1    010.00000    3
# 153   Donovan Ferreira   DC     1        1    1   0    1    010.00000    3
# 154      Digvesh Singh  LSG     1       13    2   1    1    010.00000    3
# 155     Manoj Bhandage  RCB     1        1    1   0    1    010.00000    4
#
#          SR  100s  50s  4s  6s  Rank
# ...

# %%
df[(df['No']==0) | (df['100s']>1)]
# Out:
#                Player Name  Team  Runs  Matches  Inn  No   HS          AVG  \
# 4           Mitchell Marsh   LSG   627       13   13   0  117  04080.02030
# 7        Prabhsimran Singh  PBKS   549       17   17   0   91  03020.02090
# 12           Priyansh Arya  PBKS   475       17   17   0  103  02070.09040
# 13           Aiden Markram   LSG   445       13   13   0   66  03040.02030
# 14         Abhishek Sharma   SRH   439       14   13   0  141  03030.07070
# 20             Travis Head   SRH   374       13   12   0   76  03010.01070
# 39     Vaibhav Suryavanshi    RR   252        7    7   0  101  03060.00000
# 43            Ayush Mhatre   CSK   240        7    7   0   94  03040.02090
# 47           Dewald Brevis   CSK   225        6    6   0   57  03070.05000
# 52          Faf Du Plessis    DC   202        9    9   0   62  02020.04040
# 53              Karun Nair    DC   198        8    8   0   89  02040.07050
# ...

# %%
df['Inn']=df['Inn'].sort_values()

# %%
plt.plot(df['Inn'],df['Runs'])

# %%
df[['Runs','BF']].corr()
# Out:
#           Runs        BF
# Runs  1.000000  0.990562
# BF    0.990562  1.000000
